# %% [markdown]
# This tool converts a folder of samples to a big rectangular matrix with one mono sample per row.
#
# Samples should be placed in `data/mydataset/samples/`. They could be `.mp3`, `.wav`, or anything else that ffmpeg can work with. They may be all in one folder, or in nested sub-folders.
#
# Change the path below to point to the root directory, e.g., `data/mydataset/`.
#
# The samplerate `sr` is not necessarily the native samplerate of the samples, it's the samplerate you want to load them at.
#
# The output of this notebook is:
# * `data/mydataset/durations.txt`
# * `data/mydataset/filenames.txt`
# * `data/mydataset/samples.npy`

# %%
data_root = '/home/tracek/Data/Birdman/'
sr = 16000
max_length = sr * 4 # ignore samples longer than 4 seconds
fixed_length = sr // 4 # trim all samples to 250 milliseconds
limit = None # set this to 100 to only load the first 100 samples

# %%
import numpy as np
from os.path import join
from multiprocessing import Pool
from utils import list_all_files, ffmpeg_load_audio

# %%
files = list(list_all_files(join(data_root, 'samples'), ['.wav']))
len(files)
# Out:
# 142

# %%
def load_sample(fn, sr=None,
                max_length=None, fixed_length=None, normalize=True):
    if fn == '': # ignore empty filenames
        return None
    audio, _ = ffmpeg_load_audio(fn, sr, mono=True)
    duration = len(audio)
    if duration == 0: # ignore zero-length samples
        return None
    if max_length and duration >= max_length: # ignore long samples
        return None
    if fixed_length:
        audio.resize(fixed_length)
    max_val = np.abs(audio).max()
    if max_val == 0: # ignore completely silent sounds
        return None
    if normalize:
        audio /= max_val
    return (fn, audio, duration)

# %%
def job(fn):
    return load_sample(fn, sr=sr,
                       max_length=max_length, fixed_length=fixed_length)
pool = Pool()
# %time results = pool.map(job, files[:limit])
print('Processed', len(results), 'samples')
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 1.31 s
# Processed 142 samples

# %%
valid = filter(None, results)
filenames = [x[0] for x in valid]
samples = [x[1] for x in valid]
durations = [x[2] for x in valid]
samples = np.asarray(samples)
np.savetxt(join(data_root, 'filenames.txt'), filenames, fmt='%s')
np.savetxt(join(data_root, 'durations.txt'), durations, fmt='%i')
# %time np.save(join(data_root, 'samples.npy'), samples)
print('Saved', len(valid), 'samples')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 357 µs
# TypeErrorTraceback (most recent call last)
# <ipython-input-10-0c4b904d300f> in <module>()
#       7 np.savetxt(join(data_root, 'durations.txt'), durations, fmt='%i')
#       8 get_ipython().magic("time np.save(join(data_root, 'samples.npy'), samples)")
# ----> 9 print('Saved', len(valid), 'samples')
#
# TypeError: object of type 'filter' has no len()

# %%
results
# Out:
# [('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.740_081.844.wav',
#   array([ 0.03625674,  0.01518863, -0.02155806, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1675),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_082.187_082.937.wav',
#   array([ 0.03028798,  0.02805362,  0.04046673, ...,  0.00148957,
#           0.00049652, -0.01812314], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_010.456_010.567.wav',
#   array([-0.12734452, -0.05100362,  0.03553801, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1780),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_068.037_068.787.wav',
#   array([ 0.01075269, -0.15591398, -0.01612903, ...,  0.31182796,
#          -0.2311828 ,  0.0483871 ], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.123_008.444.wav',
#   array([-0.09440559, -0.52797204,  0.22377622, ...,  0.15734266,
#          -0.00699301, -0.24825175], dtype=float32),
#   5138),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_034.567_034.806.wav',
#   array([-0.02946955,  0.01964637,  0.12770137, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3815),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_003.267_003.427.wav',
#   array([-0.02581536,  0.02963986,  0.02804632, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2575),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_002.967_003.267.wav',
#   array([-0.1020646 , -0.07409257, -0.02214452, ..., -0.001998  ,
#           0.002331  , -0.0021645 ], dtype=float32),
#   4798),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_066.066_066.350.wav',
#   array([ 0.0652834 ,  0.04959514, -0.0242915 , ..., -0.03997976,
#          -0.03795547,  0.0187247 ], dtype=float32),
#   4531),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.407_081.513.wav',
#   array([-0.17161493,  0.35762483,  0.50224924, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1705),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.839_065.950.wav',
#   array([ 0.01706827,  0.0060241 , -0.01104418, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1773),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.494_049.653.wav',
#   array([-0.04470199, -0.15066226, -0.0910596 , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2535),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.618_065.734.wav',
#   array([-0.00909458, -0.07700081, -0.09741309, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1859),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.950_066.066.wav',
#   array([-0.19687915, -0.07204515,  0.09196547, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1869),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_048.887_049.043.wav',
#   array([ 0.00119332, -0.04892601, -0.22673032, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2503),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.894_050.054.wav',
#   array([-0.11352657,  0.2004831 ,  0.14734299, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2562),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.247_052.379.wav',
#   array([-0.21348314, -0.09363296, -0.51310861, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2115),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_010.567_010.741.wav',
#   array([-0.16954446, -0.14584865,  0.16366643, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2785),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_033.760_034.029.wav',
#   array([-0.0852459 , -0.2885246 , -0.04918033, ..., -0.06721312,
#           0.08360656,  0.13114753], dtype=float32),
#   4299),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_061.117_061.240.wav',
#   array([ 0.375     ,  0.13571429, -0.46785715, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1964),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_047.947_048.129.wav',
#   array([ 0.00841515,  0.06732118,  0.21458626, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2909),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_015.481_016.231.wav',
#   array([ 0.07638889, -0.1388889 , -0.34166667, ..., -0.04027778,
#           0.03194445,  0.08194444], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.844_081.952.wav',
#   array([-0.42890626, -0.2140625 ,  0.01875   , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1731),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.686_051.846.wav',
#   array([-0.45864663, -0.33834586,  0.01879699, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2549),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_079.910_080.660.wav',
#   array([-0.04520795,  0.07414105,  0.1283906 , ..., -0.15189873,
#           0.06148282, -0.01446655], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_031.467_032.175.wav',
#   array([-0.2087156 ,  0.06880734,  0.02981651, ..., -0.33027524,
#          -0.07568807,  0.27293578], dtype=float32),
#   11318),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_010.269_010.456.wav',
#   array([-0.05383104, -0.03654224, -0.01414538, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3002),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_017.952_018.171.wav',
#   array([-0.01473543,  0.04219692,  0.0435365 , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3504),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_048.328_048.513.wav',
#   array([-0.07056452,  0.47782257,  0.26209676, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2960),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_030.647_031.046.wav',
#   array([ 0.12658228, -0.05063291, -0.17721519, ..., -0.15506329,
#           0.12658228, -0.01265823], dtype=float32),
#   6373),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_032.279_033.029.wav',
#   array([-0.18161926,  0.32458061,  0.51130563, ...,  0.02771699,
#          -0.02625821, -0.02990518], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_034.196_034.356.wav',
#   array([-0.29606098, -0.30241424, -0.11435832, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2549),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_017.462_017.604.wav',
#   array([-0.20072992,  0.56934309,  0.90510947, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2280),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_003.599_003.781.wav',
#   array([-0.13932934, -0.04081102,  0.13101117, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2911),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_087.393_088.143.wav',
#   array([-0.00581937,  0.00139665, -0.00046555, ..., -0.01675978,
#          -0.00558659, -0.00116387], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_046.014_046.764.wav',
#   array([-0.15718158, -0.14363144, -0.15989161, ...,  0.05149052,
#          -0.06504065, -0.1897019 ], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.558_089.659.wav',
#   array([ 0.10007269,  0.14393021, -0.00823843, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1620),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_020.816_021.093.wav',
#   array([-0.54094827,  0.16810344,  0.60560346, ...,  0.1099138 ,
#           0.17672414, -0.1487069 ], dtype=float32),
#   4433),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.585_008.710.wav',
#   array([ 0.03284672,  0.01277372,  0.02554744, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2005),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.005_089.172.wav',
#   array([-0.07592304,  0.52548105,  0.47347894, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2673),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_088.542_088.838.wav',
#   array([ 0.02490887,  0.0227825 , -0.0045565 , ..., -0.00972054,
#          -0.0145808 ,  0.0082017 ], dtype=float32),
#   4742),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.559_051.686.wav',
#   array([ 0.295302  ,  0.21140939,  0.18120806, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2041),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_013.111_013.861.wav',
#   array([ 0.23121387,  0.53757226, -0.20809248, ...,  0.1734104 ,
#           0.15606935,  0.31791908], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_020.335_020.644.wav',
#   array([-0.01028807, -0.00205761,  0.01406036, ...,  0.00857339,
#          -0.010631  ,  0.01200274], dtype=float32),
#   4938),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_009.990_010.269.wav',
#   array([ 0.02178318,  0.02684904,  0.00683891, ...,  0.01317123,
#           0.00379939, -0.00810537], dtype=float32),
#   4455),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.017_065.230.wav',
#   array([-0.05924856, -0.08128612, -0.03594653, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3402),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_034.356_034.567.wav',
#   array([-0.0900277 , -0.06232687, -0.033241  , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3383),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_075.167_075.917.wav',
#   array([ 0.125    , -0.125    ,  0.1015625, ...,  0.09375  , -0.421875 ,
#          -0.1640625], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_050.806_050.986.wav',
#   array([ 0.71204191,  1.        , -0.02879581, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2885),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.659_089.781.wav',
#   array([-0.39412048, -0.22145049,  0.14391859, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1948),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_034.029_034.196.wav',
#   array([ 0.16972478,  0.16284403, -0.08830275, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2683),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_061.397_061.687.wav',
#   array([-0.24778761, -0.03539823,  0.21828909, ..., -0.55752212,
#          -0.44247788,  0.28908554], dtype=float32),
#   4632),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_058.213_058.963.wav',
#   array([-0.1111111 , -0.08333334,  0.25      , ...,  0.17222223,
#          -0.52777779, -0.21666665], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.127_081.248.wav',
#   array([ 0.11363637,  0.11363637, -0.0479798 , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1937),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.653_049.793.wav',
#   array([ 0.01991151, -0.2699115 ,  0.02654867, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2245),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_016.962_017.326.wav',
#   array([-0.15354331, -0.10236221,  0.20866142, ...,  0.01968504,
#          -0.12992126,  0.26377952], dtype=float32),
#   5831),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.818_008.947.wav',
#   array([ 0.09096535,  0.16769803,  0.15903465, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2064),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.793_049.894.wav',
#   array([-0.31105992, -0.29262674,  0.07834101, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1612),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_018.171_018.921.wav',
#   array([-0.04542873, -0.04542873, -0.0374787 , ...,  0.01306076,
#          -0.0028393 , -0.02271437], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_086.826_086.930.wav',
#   array([ 0.22102624,  0.28442937,  0.05470363, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1668),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_053.120_053.870.wav',
#   array([-0.10526316,  0.03508772, -0.06140351, ...,  0.32894737,
#          -0.2850877 , -0.61403507], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.511_065.618.wav',
#   array([-0.00091519,  0.36089078,  0.33770591, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1720),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.335_049.494.wav',
#   array([-0.06404959,  0.31611571,  0.17975207, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2541),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_061.687_062.437.wav',
#   array([ 0.15753424,  0.04337899, -0.17351598, ..., -0.04794521,
#          -0.02283105, -0.07990868], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.379_052.483.wav',
#   array([-0.22413793,  0.21034482,  0.00689655, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1653),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_050.679_050.806.wav',
#   array([ 0.07323944, -0.21971831, -0.56901407, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2026),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_021.093_021.843.wav',
#   array([-0.1573604 , -0.2538071 ,  0.81218272, ...,  0.02538071,
#          -0.01015228, -0.20812182], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_031.046_031.467.wav',
#   array([ 0.57507986,  0.55591053,  0.06389777, ...,  0.05750799,
#           0.06070287, -0.28434506], dtype=float32),
#   6747),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_015.094_015.286.wav',
#   array([-0.2628651 , -0.15020862,  0.10013908, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3072),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.142_052.247.wav',
#   array([ 0.19333333, -0.41666666, -0.28      , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1690),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_041.915_042.665.wav',
#   array([-0.08310992,  0.19034852,  0.0080429 , ...,  0.22788204,
#          -0.04289544,  0.15549597], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.838_052.983.wav',
#   array([ 0.06302521,  0.25630254,  0.10084034, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2326),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_080.911_081.127.wav',
#   array([ 0.02301118, -0.00460224,  0.06245891, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3452),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_077.444_078.194.wav',
#   array([-0.12179487, -0.03846154, -0.15384616, ...,  0.24358974,
#          -0.34615386, -0.0448718 ], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_050.986_051.187.wav',
#   array([-0.44057971, -0.11014493, -0.46376812, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3219),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_003.781_003.886.wav',
#   array([-0.0297816 ,  0.09596294,  0.15221708, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1678),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_066.350_067.100.wav',
#   array([-0.02659575, -0.83510643, -0.41489363, ...,  0.32978722,
#          -0.30851066, -0.12765957], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_060.952_061.117.wav',
#   array([ 0.25850341, -0.24829932, -0.26190478, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2653),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.043_049.182.wav',
#   array([-0.32524273, -0.35113269, -0.18770227, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2213),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_034.806_035.556.wav',
#   array([-0.2857143 , -0.16071428,  0.31632653, ...,  0.07397959,
#           0.29591838,  0.11734694], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_023.162_023.912.wav',
#   array([ 0.17      ,  0.34999999,  0.54666668, ..., -0.07333333,
#          -0.13666667,  0.13      ], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.513_081.632.wav',
#   array([-0.01747234, -0.00349447, -0.00465929, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1895),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_055.995_056.147.wav',
#   array([ 0.00180941,  0.0615199 , -0.00784077, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2443),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_086.659_086.826.wav',
#   array([-0.4291735 ,  0.09084523,  0.50362915, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2672),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_010.946_011.145.wav',
#   array([-0.07974138, -0.0809387 ,  0.04334291, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3192),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_004.215_004.965.wav',
#   array([ 0.1414791 ,  0.04823151,  0.05787781, ...,  0.06752411,
#          -0.36012861, -0.06430868], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_015.286_015.481.wav',
#   array([-0.15588236, -0.0382353 ,  0.02647059, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3131),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_049.182_049.335.wav',
#   array([ 0.01208054, -0.15436241, -0.03489933, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2458),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.172_089.277.wav',
#   array([ 0.20406568,  0.05003909, -0.24198593, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1679),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_087.265_087.393.wav',
#   array([-0.42287514, -0.31969219,  0.13606156, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2047),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.983_053.120.wav',
#   array([-0.17021276,  0.17021276,  0.59574467, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2195),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_071.655_072.405.wav',
#   array([-0.2651515 ,  0.67424244,  0.43939394, ...,  0.00757576,
#           0.21969697, -0.34090909], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_048.657_048.887.wav',
#   array([ 0.03857868, -0.12588832, -0.32994923, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3680),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.632_081.740.wav',
#   array([-0.52082509, -0.41451806,  0.16739389, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1724),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_010.741_010.946.wav',
#   array([-0.07682646, -0.08582792, -0.03809923, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3267),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_003.427_003.599.wav',
#   array([ 0.13605763,  0.04310854, -0.04263612, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2748),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_079.772_079.910.wav',
#   array([-0.01473684,  0.0568421 , -0.06736842, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2209),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_017.326_017.462.wav',
#   array([ 0.02816901, -0.24547283, -0.21327968, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2169),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_086.930_087.047.wav',
#   array([-0.08683474, -0.09866168, -0.01742919, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1877),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.710_008.818.wav',
#   array([-0.13814016, -0.09973046,  0.28301886, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1722),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.993_052.142.wav',
#   array([ 0.09965636,  0.37800688,  0.27491409, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2383),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_014.731_014.902.wav',
#   array([ 0.07932692, -0.06570513, -0.06891026, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2733),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.947_009.061.wav',
#   array([-0.02493766,  0.01745636,  0.03541147, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1824),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_061.240_061.397.wav',
#   array([ 0.22097379, -0.30711609, -0.56928837, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2513),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.353_065.511.wav',
#   array([-0.28418356, -0.24784534,  0.07221057, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2521),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_014.902_015.094.wav',
#   array([-0.05394191,  0.04771784,  0.24377593, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3062),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.328_051.559.wav',
#   array([ 0.23397435,  0.07371795, -0.15705128, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3698),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_017.786_017.952.wav',
#   array([ 0.12906846,  0.14478114,  0.07631874, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2659),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_050.054_050.679.wav',
#   array([-0.05820106,  0.05820106,  0.02645503, ...,  0.33597884,
#           0.44444445,  0.41005293], dtype=float32),
#   10003),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_009.061_009.811.wav',
#   array([ 0.0361991 ,  0.07918552,  0.0158371 , ...,  0.00904977,
#           0.07239819,  0.03016591], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.230_065.353.wav',
#   array([ 0.01536773,  0.14544457,  0.1701427 , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1972),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_020.644_020.816.wav',
#   array([ 0.03448276, -0.00689655,  0.20517242, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2752),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_003.886_004.215.wav',
#   array([ 0.00144509,  0.47109827,  0.44725433, ..., -0.0050578 ,
#           0.00072254, -0.0382948 ], dtype=float32),
#   5267),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.187_051.328.wav',
#   array([-0.73800737, -0.29889297, -0.03690037, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2250),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_011.145_011.895.wav',
#   array([-0.09359606,  0.03181445,  0.1268473 , ...,  0.01313629,
#          -0.00266831, -0.00923645], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_047.534_047.764.wav',
#   array([ 0.16470589, -0.12352941,  0.06176471, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3672),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_045.879_046.014.wav',
#   array([ 0.16269842, -0.22222222, -0.23412699, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2159),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_087.156_087.265.wav',
#   array([-0.02171035, -0.06195393, -0.03627217, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1738),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.396_089.558.wav',
#   array([ 0.27288303,  0.4461576 ,  0.04331865, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2579),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_086.544_086.659.wav',
#   array([ 0.16269681,  0.07953169,  0.04683084, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1835),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.718_052.838.wav',
#   array([ 0.27692309, -0.25641027,  0.07179487, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1918),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.248_081.407.wav',
#   array([-0.22963896,  0.07052897,  0.27413937, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2537),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_014.630_014.731.wav',
#   array([-0.00806452,  0.07526882,  0.19086021, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1621),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_051.846_051.993.wav',
#   array([-0.10622711,  0.003663  , -0.08424909, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2352),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_001.101_001.851.wav',
#   array([ 0.34895834, -0.48958334, -0.015625  , ...,  0.48958334,
#           0.10416666,  0.36979166], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_060.652_060.952.wav',
#   array([-0.39627659,  0.1356383 ,  0.35904256, ...,  0.17287233,
#           0.18617021,  0.06648936], dtype=float32),
#   4785),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_048.513_048.657.wav',
#   array([-0.15591398, -0.04973118, -0.14247312, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2295),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_086.324_086.544.wav',
#   array([ 0.01306345,  0.00775194,  0.02469136, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3521),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_052.483_052.718.wav',
#   array([-0.03880597,  0.09253731,  0.01791045, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3759),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_008.444_008.585.wav',
#   array([-0.09703197, -0.07534247,  0.06621005, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2258),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_089.277_089.396.wav',
#   array([ 0.2474032 , -0.33742523, -0.56499845, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1914),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_081.952_082.187.wav',
#   array([ 0.05953654,  0.07165775,  0.03565062, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3750),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_088.838_089.005.wav',
#   array([ 0.01894947, -0.00764628, -0.00764628, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2663),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_047.764_047.947.wav',
#   array([ 0.03070175, -0.12938596, -0.1995614 , ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2930),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_056.147_056.897.wav',
#   array([-0.03033088, -0.04963235, -0.015625  , ...,  0.06433824,
#           0.01838235,  0.05055147], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_043.646_044.396.wav',
#   array([-0.14788732,  0.71830988,  0.21830986, ..., -0.22535211,
#           0.41549295,  0.26056337], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_087.047_087.156.wav',
#   array([-0.33053926,  0.1863649 ,  0.46968427, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1738),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_032.175_032.279.wav',
#   array([-0.04454149,  0.08733624, -0.04978166, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1664),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_048.129_048.328.wav',
#   array([ 0.04552846,  0.15609756,  0.14471544, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   3198),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_054.472_055.222.wav',
#   array([-0.15483871,  0.18064517, -0.18064517, ...,  0.14838709,
#           0.        , -0.47741935], dtype=float32),
#   12000),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_017.604_017.786.wav',
#   array([ 0.09747292,  0.11371841, -0.14440434, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   2914),
#  ('/home/tracek/Data/Birdman/samples/STHELENA-02_20140605_200000_1_16k_065.734_065.839.wav',
#   array([ 0.30686435,  0.36413485, -0.03432169, ...,  0.        ,
#           0.        ,  0.        ], dtype=float32),
#   1671)]
